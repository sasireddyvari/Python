# %%
from numpy.random import randn as rn
import pandas as pd
import numpy as np

# %%
rn(5,4) # 5 rows and 4 columns
# Out:
# array([[ 0.06657218, -0.40063257, -0.3824535 , -0.96602458],
#        [-0.03113433, -1.02438206, -1.43040913,  0.74617968],
#        [-0.04739718,  0.85325843, -1.2273985 , -0.27043367],
#        [-0.91095248, -0.06956951, -0.45315622,  1.39603285],
#        [-1.06920637,  0.10091505,  0.99089996, -0.32489172]])

# %%
r=rn(5,4)
r # different data gets generated but if you need same data, seed is used
# Out:
# array([[ 0.04968524,  0.35065693, -0.83816712, -0.03923377],
#        [-0.32061166, -0.21828001,  0.64719784, -1.77793831],
#        [ 0.22361264, -0.57069621,  1.43181207,  0.22228191],
#        [ 1.00158479,  0.81938885, -0.50292315,  0.72570491],
#        [ 0.93806567, -0.84333984, -1.82313087, -0.48762728]])

# %%
np.random.seed(100)
r=rn(5,4)

# %%
r
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825]])

# %%
pd.DataFrame(r)
# Out:
#           0         1         2         3
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318

# %%
row=['s','a','s','i','a']
col=['k','u','m','a']
df=pd.DataFrame(r,index=row,columns=col)
df
# Out:
#           k         u         m         a
# s -1.749765  0.342680  1.153036 -0.252436
# a  0.981321  0.514219  0.221180 -1.070043
# s -0.189496  0.255001 -0.458027  0.435163
# i -0.583595  0.816847  0.672721 -0.104411
# a -0.531280  1.029733 -0.438136 -1.118318

# %%
df[['k','u']]
# Out:
#           k         u
# s -1.749765  0.342680
# a  0.981321  0.514219
# s -0.189496  0.255001
# i -0.583595  0.816847
# a -0.531280  1.029733

# %%
df['rnew']=df['k'] + df['u']
df['r']=df['k'] + df['u']

# %%
df
# Out:
#           k         u         m         a      rnew         r
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452  0.498452

# %% [markdown]
# # drop
# ## default axis=0 i.e row

# %%
df.drop('r',axis=1)
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df
# Out:
#           k         u         m         a      rnew         r
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452  0.498452

# %% [markdown]
# # To delete from the original data , use inplace=True

# %%
df.drop('r',axis=1,inplace=True)

# %%
df
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df.iloc[1]
# Out:
# k       0.981321
# u       0.514219
# m       0.221180
# a      -1.070043
# rnew    1.495540
# Name: a, dtype: float64

# %%
df.loc[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-1f09d9ff6611> in <module>
# ----> 1 df.loc[1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962
#    1963         # fall thru to straight lookup
# -> 1964         self._validate_key(key, axis)
#    1965         return self._get_label(key, axis=axis)
#    1966
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1829
#    1830         if not is_list_like_indexer(key):
# ...

# %%
df.loc['a']
# Out:
#           k         u         m         a      rnew
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %% [markdown]
# # Extracting intersection

# %%
df
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df.loc[['a','s'],['m']]
# Out:
#           m
# a  0.221180
# a -0.438136
# s  1.153036
# s -0.458027

# %%
df.iloc[[1,2],[2]]
# Out:
#           m
# a  0.221180
# s -0.458027

# %%
df.iloc[0:3,:]
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506

# %%
df>0
# Out:
#        k     u      m      a   rnew
# s  False  True   True  False  False
# a   True  True   True  False   True
# s  False  True  False   True   True
# i  False  True   True  False   True
# a  False  True  False  False   True

# %%
df<0
# Out:
#        k      u      m      a   rnew
# s   True  False  False   True   True
# a  False  False  False   True  False
# s   True  False   True  False  False
# i   True  False  False   True  False
# a   True  False   True   True  False

# %%
df[df>0]
# Out:
#           k         u         m         a      rnew
# s       NaN  0.342680  1.153036       NaN       NaN
# a  0.981321  0.514219  0.221180       NaN  1.495540
# s       NaN  0.255001       NaN  0.435163  0.065506
# i       NaN  0.816847  0.672721       NaN  0.233252
# a       NaN  1.029733       NaN       NaN  0.498452

# %%
df[df<0]
# Out:
#           k   u         m         a      rnew
# s -1.749765 NaN       NaN -0.252436 -1.407085
# a       NaN NaN       NaN -1.070043       NaN
# s -0.189496 NaN -0.458027       NaN       NaN
# i -0.583595 NaN       NaN -0.104411       NaN
# a -0.531280 NaN -0.438136 -1.118318       NaN

# %%
df[df.loc[['i']]>0]
# Out:
#     k         u         m   a      rnew
# s NaN       NaN       NaN NaN       NaN
# a NaN       NaN       NaN NaN       NaN
# s NaN  0.255001 -0.458027 NaN  0.065506
# i NaN       NaN       NaN NaN       NaN
# a NaN       NaN       NaN NaN       NaN

# %%
df
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df[df['u']>0] # U cloumns all values are >0
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df[(df['m']>0) & (df['a']<0)]
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# i -0.583595  0.816847  0.672721 -0.104411  0.233252

# %% [markdown]
# # reset_index()

# %%
df.reset_index()
# Out:
#   index         k         u         m         a      rnew
# 0     s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# 1     a  0.981321  0.514219  0.221180 -1.070043  1.495540
# 2     s -0.189496  0.255001 -0.458027  0.435163  0.065506
# 3     i -0.583595  0.816847  0.672721 -0.104411  0.233252
# 4     a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df.reset_index(drop=True)
# Out:
#           k         u         m         a      rnew
# 0 -1.749765  0.342680  1.153036 -0.252436 -1.407085
# 1  0.981321  0.514219  0.221180 -1.070043  1.495540
# 2 -0.189496  0.255001 -0.458027  0.435163  0.065506
# 3 -0.583595  0.816847  0.672721 -0.104411  0.233252
# 4 -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df
# Out:
#           k         u         m         a      rnew
# s -1.749765  0.342680  1.153036 -0.252436 -1.407085
# a  0.981321  0.514219  0.221180 -1.070043  1.495540
# s -0.189496  0.255001 -0.458027  0.435163  0.065506
# i -0.583595  0.816847  0.672721 -0.104411  0.233252
# a -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#           k         u         m         a      rnew
# 0 -1.749765  0.342680  1.153036 -0.252436 -1.407085
# 1  0.981321  0.514219  0.221180 -1.070043  1.495540
# 2 -0.189496  0.255001 -0.458027  0.435163  0.065506
# 3 -0.583595  0.816847  0.672721 -0.104411  0.233252
# 4 -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %% [markdown]
# # Adding through list

# %%
l="sasi Kumar AI Engineer ."

# %%
df["newlist"]=l.split()

# %%
df
# Out:
#           k         u         m         a      rnew   newlist
# 0 -1.749765  0.342680  1.153036 -0.252436 -1.407085      sasi
# 1  0.981321  0.514219  0.221180 -1.070043  1.495540     Kumar
# 2 -0.189496  0.255001 -0.458027  0.435163  0.065506        AI
# 3 -0.583595  0.816847  0.672721 -0.104411  0.233252  Engineer
# 4 -0.531280  1.029733 -0.438136 -1.118318  0.498452         .

# %%
df.set_index('newlist',inplace=True)

# %%
df
# Out:
#                  k         u         m         a      rnew
# newlist
# sasi     -1.749765  0.342680  1.153036 -0.252436 -1.407085
# Kumar     0.981321  0.514219  0.221180 -1.070043  1.495540
# AI       -0.189496  0.255001 -0.458027  0.435163  0.065506
# Engineer -0.583595  0.816847  0.672721 -0.104411  0.233252
# .        -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df.loc[['sasi']]
# Out:
#                 k        u         m         a      rnew
# newlist
# sasi    -1.749765  0.34268  1.153036 -0.252436 -1.407085

# %% [markdown]
# # Data Frame Creation sample

# %%
d=pd.DataFrame({'A':[1,2,3,np.nan],'B':[np.nan,np.nan,4,5]})

# %%
d
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  4.0
# 3  NaN  5.0

# %%
d.dropna()
# Out:
#      A    B
# 2  3.0  4.0

# %%
d.dropna(axis=0,thresh=1) # 1 Not NAN vales
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  4.0
# 3  NaN  5.0

# %%
d.dropna(axis=0,thresh=2) # 2 Not NAN values
# Out:
#      A    B
# 2  3.0  4.0

# %%
d.fillna('sasi')
# Out:
#       A     B
# 0     1  sasi
# 1     2  sasi
# 2     3     4
# 3  sasi     5

# %%
d
# Out:
#      A    B
# 0  1.0  NaN
# 1  2.0  NaN
# 2  3.0  4.0
# 3  NaN  5.0

# %%
d.groupby('A').sum()
# Out:
#        B
# A
# 1.0  0.0
# 2.0  0.0
# 3.0  4.0

# %%
d.groupby('A').mean()
# Out:
#        B
# A
# 1.0  NaN
# 2.0  NaN
# 3.0  4.0

# %%
d.groupby('A').describe()
# Out:
#         B
#     count mean std  min  25%  50%  75%  max
# A
# 1.0   0.0  NaN NaN  NaN  NaN  NaN  NaN  NaN
# 2.0   0.0  NaN NaN  NaN  NaN  NaN  NaN  NaN
# 3.0   1.0  4.0 NaN  4.0  4.0  4.0  4.0  4.0

# %%
d.transpose()
# Out:
#      0    1    2    3
# A  1.0  2.0  3.0  NaN
# B  NaN  NaN  4.0  5.0

# %%
pd.concat([d,df])
# Out:
#             A    B         k         u         m         a      rnew
# 0         1.0  NaN       NaN       NaN       NaN       NaN       NaN
# 1         2.0  NaN       NaN       NaN       NaN       NaN       NaN
# 2         3.0  4.0       NaN       NaN       NaN       NaN       NaN
# 3         NaN  5.0       NaN       NaN       NaN       NaN       NaN
# sasi      NaN  NaN -1.749765  0.342680  1.153036 -0.252436 -1.407085
# Kumar     NaN  NaN  0.981321  0.514219  0.221180 -1.070043  1.495540
# AI        NaN  NaN -0.189496  0.255001 -0.458027  0.435163  0.065506
# Engineer  NaN  NaN -0.583595  0.816847  0.672721 -0.104411  0.233252
# .         NaN  NaN -0.531280  1.029733 -0.438136 -1.118318  0.498452

# %%
df1=pd.DataFrame({'key':[1,2],
                 'A':3,
                 'B':4})

# %%
df2=pd.DataFrame({'key':[1,2],
                 'C':5,
                 'D':6})

# %%
pd.merge(df1,df2)
# Out:
#    key  A  B  C  D
# 0    1  3  4  5  6
# 1    2  3  4  5  6
