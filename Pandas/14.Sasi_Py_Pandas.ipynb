# %% [markdown]
# # Pandas

# %% [markdown]
# - DataFrame
# - Series

# %%
import pandas as pd

# %%
df=pd.read_csv('sample1.csv')
df
# Out:
#    a       sasi  1
# 0  b      kumar  4
# 1  c      reddy  3
# 2  d  reddyvari  4
# 3  e     chinna  3

# %%
df.to_csv("sasi.csv")

# %%
pwd
# Out:
# 'C:\\Users\\RE20085166\\Desktop\\ML_practice\\INeuron\\Python'

# %%
pd.read_csv('sample1.csv',header=None)
# Out:
#    0          1  2
# 0  a       sasi  1
# 1  b      kumar  4
# 2  c      reddy  3
# 3  d  reddyvari  4
# 4  e     chinna  3

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    a   sasi  1
# 0  b  kumar  4
# 1  c  reddy  3

# %%
df.tail(2)
# Out:
#    a       sasi  1
# 2  d  reddyvari  4
# 3  e     chinna  3

# %%
df.dtypes
# Out:
# a       object
# sasi    object
# 1        int64
# dtype: object

# %%
df['a']
# Out:
# 0    b
# 1    c
# 2    d
# 3    e
# Name: a, dtype: object

# %%
type(df['a'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Series --One row or one column & returns indexes as well but in list we dont get the indexes

# %%
l=[1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
list(df['a'])
# Out:
# ['b', 'c', 'd', 'e']

# %%
df[['a']]
# Out:
#    a
# 0  b
# 1  c
# 2  d
# 3  e

# %%
type(df[['a']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['a','1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('a', '1')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-134-35e56b625b36> in <module>
# ----> 1 df['a','1']
#
# ...

# %%
df[['a','sasi']]
# Out:
#    a       sasi
# 0  b      kumar
# 1  c      reddy
# 2  d  reddyvari
# 3  e     chinna

# %% [markdown]
# # header,sep,index_col,skiprows

# %%
pd.read_table('sample3.tsv',header=None)
# Out:
#       0      1      2     3
# 0  sasi  kumar  reddy  vari
# 1     3      5      9   NaN

# %%
pd.read_csv('sample3.tsv',header=None) # Since commma is the seperator
# Out:
#                           0
# 0  sasi\tkumar\treddy\tvari
# 1                   3\t5\t9

# %%
pd.read_csv('sample3.tsv',header=None,sep='\t')
# Out:
#       0      1      2     3
# 0  sasi  kumar  reddy  vari
# 1     3      5      9   NaN

# %%
pd.read_excel('sample2.xlsx',header=None)
# Out:
#       0      1      2
# 0  sasi  kumat  reddy
# 1     1      3      3

# %%
pd.read_excel('sample2.xlsx',header=None,names=['col1','col2','col3','col4','col5'])
# Out:
#    col1   col2   col3  col4  col5
# 0  sasi  kumat  reddy   NaN   NaN
# 1     1      3      3   NaN   NaN

# %%
pd.read_excel('sample2.xlsx',header=None,names=['col1','col2'])
# Out:
#        col1   col2
# sasi  kumat  reddy
# 1         3      3

# %%
pd.read_csv('sample1.csv',header=None)
# Out:
#    0          1  2
# 0  a       sasi  1
# 1  b      kumar  4
# 2  c      reddy  3
# 3  d  reddyvari  4
# 4  e     chinna  3

# %%
pd.read_csv('sample4.csv')
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %%
pd.read_csv('sample4.csv',index_col=['key1','key2'])
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %% [markdown]
# # Skiprows

# %%
pd.read_csv('sample5.csv')
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
pd.read_csv('sample5.csv',skiprows=[4,5])
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 9                                                  10       11  12       foo

# %% [markdown]
# # NAN

# %%
dfr=pd.read_csv('sample6.csv')
dfr
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
dfr=pd.read_csv('sample6.csv',na_values=['one',2])
dfr
# Out:
#   something  a     b     c   d message
# 0       NaN  1   NaN   3.0   4     NaN
# 1       two  5   6.0   NaN   8   world
# 2     three  9  10.0  11.0  12     foo

# %%
dfr.isnull().sum()
# Out:
# something    1
# a            0
# b            1
# c            1
# d            0
# message      1
# dtype: int64

# %%
dfr["something"].dropna()
# Out:
# 1      two
# 2    three
# Name: something, dtype: object

# %%
dfr
# Out:
#   something  a     b     c   d message
# 0       NaN  1   NaN   3.0   4     NaN
# 1       two  5   6.0   NaN   8   world
# 2     three  9  10.0  11.0  12     foo

# %% [markdown]
# # File not found
# ## r,\ \\, /
# ## sheet_name

# %%
pd.read_excel('sample17.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-150-6b192b4495fd> in <module>
# ----> 1 pd.read_excel('sample17.xlsx')
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     822         self._io = stringify_path(io)
#     823
# --> 824         self._reader = self._engines[engine](self._io)
# ...

# %%
pwd
# Out:
# 'C:\\Users\\RE20085166\\Desktop\\ML_practice\\INeuron\\Python'

# %%
pd.read_excel('C:\Users\RE20085166\Desktop\ML_practice\INeuron\Python\ExcelFiles\sample17.xlsx')
# Out:
#   File "<ipython-input-72-b0b821a5c45d>", line 1
#     pd.read_excel('C:\Users\RE20085166\Desktop\ML_practice\INeuron\Python\ExcelFiles\sample17.xlsx')
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pd.read_excel(r'C:\Users\RE20085166\Desktop\ML_practice\INeuron\Python\ExcelFiles\sample17.xlsx',header=None)
# Out:
#       0      1      2
# 0  sasi  kumat  reddy
# 1     1      3      3

# %%
pd.read_excel('C:\\Users\\RE20085166\\Desktop\\ML_practice\\INeuron\\Python\\ExcelFiles\\sample17.xlsx',header=None)
# Out:
#       0      1      2
# 0  sasi  kumat  reddy
# 1     1      3      3

# %%
pd.read_excel('C:/Users/RE20085166/Desktop/ML_practice/INeuron/Python/ExcelFiles/sample17.xlsx',header=None)
# Out:
#       0      1      2
# 0  sasi  kumat  reddy
# 1     1      3      3

# %%
df1=pd.read_excel(r'C:\Users\RE20085166\Desktop\ML_practice\INeuron\Python\sample18.xlsx',sheet_name='Sheet2',header=None)
df1
# Out:
#               0             1               2   3      4
# 0  I am trying   to read out   data in sheet2 NaN    NaN
# 1           NaN           NaN             NaN NaN    NaN
# 2           NaN           NaN             NaN NaN    NaN
# 3           NaN          sasi             NaN NaN  kumar

# %%
df1.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3    float64
# 4     object
# dtype: object

# %%
df1[[4]]
# Out:
#        4
# 0    NaN
# 1    NaN
# 2    NaN
# 3  kumar

# %% [markdown]
# # HTML, URL

# %%
df3=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df3
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df3)
# Out:
# list

# %% [markdown]
# ### List, since from a page, if multiple tables are present then pandas creates each table in index 0, 1, 2.........
# ### pandas will be able to inspect table tab from the html url and fetched

# %%
len(df3) # No of tables in the url(html)
# Out:
# 1

# %%
df3[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df3[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df3[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df3[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
pd.isnull(df3[0])
# Out:
#         Rk  Player    Pos    Age     Tm      G     GS     MP     FG    FGA  \
# 0    False   False  False  False  False  False  False  False  False  False
# 1    False   False  False  False  False  False  False  False  False  False
# 2    False   False  False  False  False  False  False  False  False  False
# 3    False   False  False  False  False  False  False  False  False  False
# 4    False   False  False  False  False  False  False  False  False  False
# ..     ...     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 670  False   False  False  False  False  False  False  False  False  False
# 671  False   False  False  False  False  False  False  False  False  False
# 672  False   False  False  False  False  False  False  False  False  False
# 673  False   False  False  False  False  False  False  False  False  False
# 674  False   False  False  False  False  False  False  False  False  False
#
# ...

# %%
df4=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv')
df4
# Out:
#                         PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund           Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings          Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen        Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle         Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen            Mr. William Henry\tmale\t35\t0\t0\t373450\t8....
# ...                                                                    ...
# 152\t1\t1\tPears          Mrs. Thomas (Edith Wearne)\tfemale\t22\t1\t0\...
# 153\t0\t3\tMeo            Mr. Alfonzo\tmale\t55.5\t0\t0\tA.5. 11206\t8....
# 154\t0\t3\tvan Billiard   Mr. Austin Blyler\tmale\t40.5\t0\t2\tA/5. 851...
# 155\t0\t3\tOlsen          Mr. Ole Martin\tmale\t\t0\t0\tFa 265302\t7.31...
# 156\t0\t1\tWilliams       Mr. Charles Duane\tmale\t51\t0\t1\tPC 17597\t...
#
# [156 rows x 1 columns]

# %%
titanic_train=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df4=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t',chunksize=300)

# %%
df4

# %%
df4.to_csv('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-0b7b02040db3> in <module>
# ----> 1 df4.to_csv
#
# AttributeError: 'TextFileReader' object has no attribute 'to_csv'

# %% [markdown]
# # Reading only some rows - nrows

# %%
pd.read_csv('sample8.csv',nrows=1) # It loads and displays only one row
# Out:
#    a  b  c
# 0  1  2  3

# %%
pd.read_csv('sample8.csv').head(1) # It loads the entire data and displays only one row
# Out:
#    a  b  c
# 0  1  2  3

# %% [markdown]
# # to_pickle--creates a file which is binary

# %%
da=pd.read_csv('sample16_tseries.csv')
da
# Out:
#    2000-01-01  0
# 0  2000-01-02  1
# 1  2000-01-03  2
# 2  2000-01-04  3
# 3  2000-01-05  4
# 4  2000-01-06  5
# 5  2000-01-07  6

# %%
da.to_pickle("C:\\Users\\RE20085166\\Desktop\\ML_practice\\INeuron\\Python\\Files\\picklefile")

# %%
# pickle file is a binary encoded file. To read it we need an api doing serde operation i.e serialisation and deserialisation or pandas library

# %%
pd.read_pickle("C:\\Users\\RE20085166\\Desktop\\ML_practice\\INeuron\\Python\\Files\\picklefile")
# Out:
#    2000-01-01  0
# 0  2000-01-02  1
# 1  2000-01-03  2
# 2  2000-01-04  3
# 3  2000-01-05  4
# 4  2000-01-06  5
# 5  2000-01-07  6
